# %% [markdown]
# #### Windows:
# É necessário ter o latex intalado (MikTex). Após a instalação foi preciso reiniciar a máquina.
# Na primeira vez que rodei o código, o pdflatex solicitou a instalação de vários pacotes, apenas clique em Install em todas as janelas que aparecerem.
# #### Linux:
# Trocar %%cmd por %%bash

# %%
# %%cmd
# jupyter nbconvert --to latex --template papertemplate-2.tplx MotionRetargetingPaper-3.ipynb --TagRemovePreprocessor.remove_cell_tags="{'remove_cell'}
# pdflatex MotionRetargetingPaper-3.tex
# bibtex MotionRetargetingPaper-3
# pdflatex MotionRetargetingPaper-3.tex
# pdflatex MotionRetargetingPaper-3.tex
# pdflatex MotionRetargetingPaper-3.tex
# Out:
# Microsoft Windows [versÆo 10.0.17134.829]
# (c) 2018 Microsoft Corporation. Todos os direitos reservados.
#
# (mrpy3) C:\Users\Paula D. Paro Costa\Desktop\MotionRetargeting\dev>jupyter nbconvert --to latex --template papertemplate-2.tplx MotionRetargetingPaper-3.ipynb --TagRemovePreprocessor.remove_cell_tags="{'remove_cell'}
#
# (mrpy3) C:\Users\Paula D. Paro Costa\Desktop\MotionRetargeting\dev>pdflatex MotionRetargetingPaper-3.tex
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (MiKTeX 2.9.7050 64-bit)
# entering extended mode
# (MotionRetargetingPaper-3.tex
# LaTeX2e <2018-12-01>
# (vgtc.cls
# Document Class: vgtc 2006/05/21 IEEE VGTC
#
# ("C:\Users\Paula D. Paro Costa\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base
# \article.cls"
# Document Class: article 2018/09/03 v1.4i Standard LaTeX document class
#
# ("C:\Users\Paula D. Paro Costa\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base
# \size10.clo")))
# ...
